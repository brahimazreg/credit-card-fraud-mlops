# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\brahi\Desktop\credit-card-fraud-mlops\data\raw\creditcard.csv")

# %%
x=df.drop('Class',axis=1)
y=df['Class']

x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,test_size=0.2,random_state=42)

# %% [markdown]
# We need to scale Amount only because other features are already scaled

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train["Amount"]=scaler.fit_transform(x_train[["Amount"]])
x_test["Amount"]=scaler.transform(x_test[["Amount"]])

# %%
#    Verify data first (quick check for x_train and x_test  to confirm the scale for Amount feature)
x_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 265518  161919.0  1.946747 -0.752526 -1.355130 -0.661630  1.502822  4.024933
# 180305  124477.0  2.035149 -0.048880 -3.058693  0.247945  2.943487  3.298697
# 42664    41191.0 -0.991920  0.603193  0.711976 -0.992425 -0.825838  1.956261
# 198723  132624.0  2.285718 -1.500239 -0.747565 -1.668119 -1.394143 -0.350339
# 82325    59359.0 -0.448747 -1.011440  0.115903 -3.454854  0.715771 -0.147490
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 265518 -1.479661  1.139880  1.406819  ... -0.134435  0.076197  0.297537
# 180305 -0.002192  0.674782  0.045826  ... -0.227279  0.038628  0.228197
# 42664  -2.212603 -5.037523  0.000772  ...  1.280856 -2.798352  0.109526
# 198723 -1.427984  0.010010 -1.118447  ... -0.490642 -0.139670  0.077013
# 82325   0.504347 -0.113817 -0.044782  ... -0.275297 -0.243245 -0.173298
#
# ...

# %%
x_test.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 263020  160760.0 -0.674466  1.408105 -1.110622 -1.328366  1.388996 -1.308439
# 11378    19847.0 -2.829816 -2.765149  2.537793 -1.074580  2.842559 -2.153536
# 147283   88326.0 -3.576495  2.318422  1.306985  3.263665  1.127818  2.865246
# 219439  141734.0  2.060386 -0.015382 -1.082544  0.386019 -0.024331 -1.074935
# 36939    38741.0  1.209965  1.384303 -1.343531  1.763636  0.662351 -2.113384
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 263020  1.885879 -0.614233  0.311652  ...  0.394322  0.080084  0.810034
# 11378  -1.795519 -0.250020  3.073504  ... -0.515765 -0.295555  0.109305
# 147283  1.444125 -0.718922  1.874046  ...  2.034786 -1.060151  0.016867
# 219439  0.207792 -0.338140  0.455091  ... -0.192024 -0.281684 -0.639426
# 36939   0.854039 -0.475963 -0.629658  ...  0.009083 -0.164015 -0.328294
#
# ...

# %%
# chek for Nan value in both x_train and x_test
x_train.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %% [markdown]
# ### Handle class imbalance
# Because the  dataset is highly imbalanced (~0.17% fraud)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_train_res, y_train_res = smote.fit_resample(x_train, y_train)

# %%
#    Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train_res, y_train_res)
# Out:
# C:\Users\brahi\Desktop\Predict_Employee_Resign_appv2\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.08      0.91      0.15        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.95      0.57     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[55859  1005]
#  [    9    89]]

# %%
roc_auc_score(y_test, model.predict_proba(x_test)[:, 1])
# Out:
# np.float64(0.9749760976422084)

# %% [markdown]
# We Try better other models :
#
# - Random Forest
# - XGBoost

# %% [markdown]
# ####    RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

RFC =RandomForestClassifier(criterion='gini',max_depth=6,min_samples_leaf=10,random_state=42 )
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=10, random_state=42)

# %%
y_pred_rfc=RFC.predict(x_test)

# %%
print(classification_report(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.88      0.76      0.81        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.88      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# #### XGBoost

# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#      -------------------------------------- 101.7/101.7 MB 7.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: C:\Users\brahi\Desktop\Predict_Employee_Resign_appv2\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)

model.fit(x_train, y_train)
y_pred_xgb = model.predict(x_test)

# %%
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.79      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    scale_pos_weight=100
)

model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_proba = model.predict_proba(x_test)[:, 1]

# %%
y_pred_th = (y_proba > 0.3).astype(int)

# %%
print(classification_report(y_test, y_pred_th))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.85      0.85      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.92      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[55859  1005]
#  [    9    89]]

# %%
print(confusion_matrix(y_test, y_pred_th))
# Out:
# [[56849    15]
#  [   15    83]]

# %%
import joblib
joblib.dump(model, "xgboost_model.pkl")
# Out:
# ['xgboost_model.pkl']

# %%
# Save threshold
joblib.dump(0.3, "threshold.pkl")
# Out:
# ['threshold.pkl']

# %% [markdown]
# #### Conclusion:
# The final model selected for deployment was XGBoost. Probability predictions were converted into fraud labels using a tuned decision threshold of 0.30 instead of the default 0.50. This threshold provided a better balance between precision and recall, achieving approximately 0.85 precision and 0.85 recall on the test set.

# %%
# save scalar
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# check if saved documents can be correctelly loaded and tested
model = joblib.load("xgboost_model.pkl")
threshold = joblib.load("threshold.pkl")
scaler = joblib.load("scaler.pkl")

# %%
sample = x_test.head(5)

proba = model.predict_proba(sample)[:, 1]
pred = (proba > threshold).astype(int)

print(proba)
print(pred)
# Out:
# [2.0014117e-05 6.5352060e-06 5.7792127e-05 2.2037939e-05 1.3725160e-04]
# [0 0 0 0 0]
