# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the dataset and the 5 first rows

# %%
df=pd.read_csv(r"C:\Users\brahi\Desktop\credit-card-fraud-mlops\data\raw\creditcard.csv")
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# Check if there is null values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Check how many classes are there

# %%
df.Class.value_counts(normalize=True)*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %% [markdown]
# The dataset is highly imbalanced, with fraud cases representing less than 1% of the data. This creates a challenging classification problem where standard accuracy is not the best metric to use . Therefore, precision-recall-based metrics and imbalance-handling techniques will be required.
#  - so accuracy is not enough
#  - I will use PR-AUC
#  - I will apply class weighting / SMOTE
#  - I will tune decision threshold

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 294.9/294.9 kB 8.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: C:\Users\brahi\Desktop\Predict_Employee_Resign_appv2\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x="Class",
    hue="Class",
    data=df,
    palette=["green", "red"],
    legend=False
)

plt.title("Fraud vs Non-Fraud Transactions")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# Conclusion:
# The dataset is extremely imbalanced, with fraudulent transactions representing less than 1% of all transactions.

# %%
sns.histplot(df["Amount"], bins=50)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
df.Amount.describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# 75% of transactions have an amount lower than 77.17, while the maximum transaction amount is 25,691.16. This large difference indicates the presence of extreme high-value outliers in the dataset.

# %%
import numpy as np

sns.histplot(np.log1p(df["Amount"]), bins=50)
plt.title("Log-Transformed Transaction Amount")
plt.show()

# %% [markdown]
# Amount by Class to see if fraudulent transactions generally smaller or larger than normal transactions?
# - Amount is heavily right-skewed.
# - Log transformation makes the distribution easier to analyze.

# %%
sns.boxplot(x="Class", y="Amount", data=df)
plt.title("Amount Distribution by Class")
plt.show()

# %% [markdown]
# Time distribution

# %%
sns.histplot(df["Time"], bins=50)
plt.title("Transaction Time Distribution")
plt.show()

# %% [markdown]
# convert to hours

# %%
df["Hour"] = df["Time"] / 3600

# %%
sns.histplot(df["Hour"], bins=24)
plt.title("Transactions by Hour")
plt.show()

# %%
sns.boxplot(x="Class", y="Hour", data=df)
plt.show()

# %%
for col in ["V1", "V2", "V3", "V4"]:
    plt.figure(figsize=(6,3))
    sns.histplot(df[col], bins=50, kde=True)
    plt.title(f"{col} | Skewness = {df[col].skew():.2f}")
    plt.show()

# %%
corr = df.corr()["Class"].sort_values()

top_negative = corr.head(10)
top_positive = corr.tail(10)

print(top_negative)
print(top_positive)
# Out:
# V17   -0.326481
# V14   -0.302544
# V12   -0.260593
# V10   -0.216883
# V16   -0.196539
# V3    -0.192961
# V7    -0.187257
# V18   -0.111485
# V1    -0.101347
# V9    -0.097733
# Name: Class, dtype: float64
# V28      0.009536
# V27      0.017580
# V8       0.019875
# V20      0.020090
# V19      0.034783
# V21      0.040413
# V2       0.091289
# V4       0.133447
# V11      0.154876
# Class    1.000000
# Name: Class, dtype: float64

# %% [markdown]
# Show the outliers

# %%
Q1 = df["Amount"].quantile(0.25)
Q3 = df["Amount"].quantile(0.75)

IQR = Q3 - Q1

outliers = df[
    (df["Amount"] < Q1 - 1.5 * IQR) |
    (df["Amount"] > Q3 + 1.5 * IQR)
]

print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 31904

# %% [markdown]
# #### Conclusion :
# 1. Dataset contains no missing values.
# 2. Target class is extremely imbalanced (~0.17% fraud).
# 3. Amount distribution is heavily right-skewed.
# 4. Fraud and non-fraud transactions show different patterns for several PCA features.
# 5. Strong correlations exist between Class and features such as V14, V17, V12.
# 6. Outliers are present, especially in Amount.
# 7. Stratified splitting will be required.
# 8. Evaluation should focus on Precision, Recall, F1-score, and ROC-AUC rather than Accuracy.
# 9. Class imbalance techniques (SMOTE, class weights, undersampling) should be considered.

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Class", axis=1)
y = df["Class"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    stratify=y,
    test_size=0.2,
    random_state=42
)

print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# Class
# 0    0.998271
# 1    0.001729
# Name: proportion, dtype: float64
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64
